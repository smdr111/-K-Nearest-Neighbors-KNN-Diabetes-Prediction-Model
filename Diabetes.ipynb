# %% [markdown]
# <a href="https://colab.research.google.com/github/smdr111/-K-Nearest-Neighbors-KNN-Diabetes-Prediction-Model/blob/main/Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# Data Processing

# %%
df = pd.read_csv('/content/diabetes.csv')

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
corr_matrix = df.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_12b7a_row0_col0, #T_12b7a_row1_col1, #T_12b7a_row2_col2, #T_12b7a_row3_col3, #T_12b7a_row4_col4, #T_12b7a_row5_col5, #T_12b7a_row6_col6, #T_12b7a_row7_col7, #T_12b7a_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_12b7a_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_12b7a_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_12b7a_row0_col3, #T_12b7a_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_12b7a_row0_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_12b7a_row0_col5, #T_12b7a_row0_col6, #T_12b7a_row1_col3, #T_12b7a_row2_col8, #T_12b7a_row3_col1, #T_12b7a_row5_col0, #T_12b7a_row5_col7, #T_12b7a_row6_col2, #T_12b7a_row6_col7, #T_12b7a_row7_col4, #T_12b7a_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_12b7a_row0_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_12b7a_row0_col8 {
# ...

# %%
df.corrwith(df['Outcome']).sort_values(ascending=False)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# dtype: float64

# %%
# choosing the columns for the model those have good corraltion with Column 'Outcome'
df = df[['Outcome','Glucose','BMI','Age','Pregnancies']]

# %% [markdown]
# Data Preparation for ML

# %%
X = df.drop('Outcome',axis=1)
y = df['Outcome']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ML

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=42, stratify=y)

# %%
# k-NN
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict = knn.predict(X_test)

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Jaccard Index

# %%
from sklearn.metrics import jaccard_score
jaccard_score(y_test,y_predict)
# Out:
# np.float64(0.5)

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_predict)
# Out:
# array([[43,  7],
#        [10, 17]])

# %% [markdown]
# Precision,recall,F1

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
precision = precision_score(y_test, y_predict)
recall = recall_score(y_test, y_predict)
f1 = f1_score(y_test, y_predict)
accuracy = accuracy_score(y_test, y_predict)
print(f"{precision=}\n{recall=}\n{f1=}\n{accuracy=}")
# Out:
# precision=0.7083333333333334
# recall=0.6296296296296297
# f1=0.6666666666666666
# accuracy=0.7792207792207793

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83        50
#            1       0.71      0.63      0.67        27
#
#     accuracy                           0.78        77
#    macro avg       0.76      0.74      0.75        77
# weighted avg       0.78      0.78      0.78        77

# %% [markdown]
# Cross-Validation

# %%
# Cross validation
from sklearn.model_selection import cross_val_predict
predict = cross_val_predict(estimator = knn, X = X, y = y, cv = 5)

# Model evaluation
from sklearn.metrics import classification_report
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80       500
#            1       0.64      0.60      0.62       268
#
#     accuracy                           0.74       768
#    macro avg       0.72      0.71      0.71       768
# weighted avg       0.74      0.74      0.74       768
